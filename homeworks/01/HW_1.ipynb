# %%
import sys
import random
class HashMap:
    class Entry:
        def __init__(self, key, value):
            self.key = key
            self.value = value
            #TODO store key and value as attributes
            
        def get_key(self):
            return self.key
            #TODO return key
            
        def get_value(self):
            return self.value
            #TODO return value
            
        def __eq__(self, other):
            return self.key == other.key
            #TODO реализовать функцию сравнения
            #Пояснения: self - текущий объект entry, other - какой-то другой объект
            #Какое условие на равенство объектов в ассоциативном массиве?
            #Если объекты равны, то метод должен возвращать True, иначе False
        def __repr__(self):
            return "object!"
    
    def __init__(self, bucket_num = 64):
        self.bucket_num = bucket_num
        self.bucket_array = [[self.Entry('','') for k in range(1)] for i in range(bucket_num)]
        self.count = 0
        #TODO Создать массив для бакетов

    def get(self, key, default_value=None):
        flag = 0
        for i in range(self.bucket_num):
            for k in range(len(self.bucket_array[i])):
                if self.bucket_array[i][k].get_key() == key :
                    flag = 1
                    break
            if self.bucket_array[i][k].get_key() == key:
                break
        if flag:
            return self.bucket_array[i][k].get_value()
        else:
            return default_value
        #TODO метод get, возвращающий значение, если оно присутствует, иначе default_value
    def show(self):
        for i in range(self.bucket_num):
            sys.stdout.write("{}. ".format(i))
            for k in range(len(self.bucket_array[i])):
                if self.bucket_array[i][k].get_key() == '':
                    sys.stdout.write("Entry is empty, ")
                else:
                    sys.stdout.write("Key =  {} and value = {}, ".format(self.bucket_array[i][k].get_key(),self.bucket_array[i][k].get_value()))
            print('')
        
    def __str__(self):
        return str(self.__len__)
        #TODO Метод, вызываемый при вызове print, пофантазируйте, что можно написать

    def put(self, key, value):
        index = self._get_index(self._get_hash(key))
        if self.bucket_array[index][0].get_key() == '':
            self.bucket_array[index].insert(0,self.Entry(key,value))
            self.bucket_array[index].pop(1)
        else:
            flag = 0
            for i in range(len(self.bucket_array[index])):
                if self.bucket_array[index][i].get_key() == key:
                    flag = 1
                    break
            if flag:
                self.bucket_array[index].insert(i, self.Entry(key, value))
            else:
                self.bucket_array[index].append(self.Entry(key, value))
        self.count = self.count + 1
        #TODO метод put, кладет значение по ключу, в случае, если ключ уже присутствует он его заменяет

    def __len__(self):
        return self.count
        #TODO Возвращает количество Entry в массиве

    def _get_hash(self, key):
        a = list(str(key))
        sum = 0
        for i in a:
            sum = sum + ord(i)
        return sum
        #TODO Вернуть хеш от ключа, по которому он кладется в бакет

    def _get_index(self, hash_value):
        return int(hash_value % self.bucket_num)
        #TODO По значению хеша вернуть индекс элемента в массиве



    def values(self):
        return [j.get_value() for i in self.bucket_array for j in i if j.get_value() != '']
        #TODO Задание со звездочкой!
        #Должен возвращать генератор или итератор значений (на самом деле итератор, но не принципиально, через генераторы проще ИМХО)

    def keys(self):
        return [j.get_key() for i in self.bucket_array for j in i if j.get_key() != '']
        #TODO Задание со звездочкой!
        #Должен возвращать генератор или итератор ключей (на самом деле итератор, но не принципиально, через генераторы проще ИМХО)
        
    def items(self):
        return [(j.get_key(), j.get_value()) for i in self.bucket_array for j in i if j.get_key() != '']
        #TODO Задание со звездочкой!
        #Должен возвращать генератор или итератор пар ключ и значение (tuples)
        #(на самом деле итератор, но не принципиально, через генераторы проще ИМХО)

# %%
class HashSet(HashMap):
   
    def get(self, key, default_value=None):
        flag = 0
        for i in range(self.bucket_num):
            for k in range(len(self.bucket_array[i])):
                if self.bucket_array[i][k].get_key() == key :
                    flag = 1
                    break
            if self.bucket_array[i][k].get_key() == key:
                break
        if flag:
            return self.bucket_array[i][k].get_key()
        else:
            return default_value   
        #возвращает либо key, либо None, в случае отсутствия key в массиве     
        #TODO достаточно переопределить данный метод

    def put(self, key, default_value = None):
        index = self._get_index(self._get_hash(key))
        if self.bucket_array[index][0].get_key() == '':
            self.bucket_array[index].insert(0,self.Entry(key,default_value))
            self.bucket_array[index].pop(1)
        else:
            flag = 0
            for i in range(len(self.bucket_array[index])):
                if self.bucket_array[index][i].get_key() == key:
                    flag = 1
                    break
            if flag:
                self.bucket_array[index].insert(i, self.Entry(key, default_value))
            else:
                self.bucket_array[index].append(self.Entry(key, default_value))
        self.count = self.count + 1
        #TODO метод put, нужно переопределить данный метод

    def __len__(self):
        return self.count
        #TODO Возвращает количество Entry в массиве

    def values(self):
        return [j.get_key() for i in self.bucket_array for j in i if j.get_key() != '']
        #TODO Задание со звездочкой!
        #Если делали, то нужно бы переопределить
        #Должен возвращать генератор или итератор значений (на самом деле итератор, но не принципиально, через генераторы проще ИМХО)
