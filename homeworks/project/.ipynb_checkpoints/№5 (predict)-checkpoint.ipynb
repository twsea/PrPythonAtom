# %%
import requests
from bs4 import BeautifulSoup
import json
import re
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
import nltk
#nltk.download('wordnet')
#nltk.download('stopwords')
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer

# %%
data = pd.read_csv('film_reviews_200_cut.csv',  sep='\t')

# %%
data
# Out:
#                                                   name  \
# 0                                         Finding Nemo
# 1                                      The Incredibles
# 2                                           Iron Man 3
# 3           Pirates of the Caribbean: Dead Man's Chest
# 4                                        Spirited Away
# 5                   Mission: Impossible - Rogue Nation
# 6                                  It's Christmas, Eve
# 7          Fantastic Beasts: The Crimes of Grindelwald
# 8                                         The Predator
# 9                                         Aan Devathai
# 10                          Rambo: First Blood Part II
# 11                         Sicario: Day of the Soldado
# 12                   The Hobbit: An Unexpected Journey
# 13   The Lord of the Rings: The Fellowship of the Ring
# 14                                            Replicas
# 15                      Jurassic World: Fallen Kingdom
# 16                                      Thor: Ragnarok
# 17                                    Django Unchained
# 18        Harry Potter and the Deathly Hallows: Part 1
# 19    Pirates of the Caribbean: Dead Men Tell No Tales
# 20               Hotel Transylvania 3: Summer Vacation
# 21                                   Pariyerum Perumal
# 22                        Death Race 4: Beyond Anarchy
# 23                                       Hunter Killer
# 24             Maquia: When the Promised Flower Blooms
# 25               The Hunger Games: Mockingjay - Part 1
# 26                                     The Equalizer 2
# 27                                             Rampage
# 28                               The Dark Knight Rises
# 29              Harry Potter and the Half-Blood Prince
# ..                                                 ...
# 171                             Exodus: Gods and Kings
# 172                                Mission: Impossible
# 173                                        First Blood
# 174        The Seven Deadly Sins: Prisoners of the Sky
# 175                                      Batman Begins
# 176                                 The Imitation Game
# 177                                      Incredibles 2
# 178                                            Ant-Man
# 179                                   Ready Player One
# 180           Harry Potter and the Philosopher's Stone
# 181                           The Shawshank Redemption
# 182                                 The Purge: Anarchy
# 183                                Sorry to Bother You
# 184           Pirates of the Caribbean: At World's End
# 185                                          Overboard
# 186                     War for the Planet of the Apes
# 187                                          Star Wars
# 188                                          Gone Girl
# 189                           Star Wars: The Last Jedi
# 190                                           Creed II
# 191                                          Halloween
# 192                                      The Godfather
# 193                                            Mile 22
# 194                                          The Purge
# 195               Mission: Impossible - Ghost Protocol
# 196                                           Overlord
# 197                                     Justice League
# 198                                       Blade Runner
# 199                       Star Wars: The Force Awakens
# 200                             Billy: The Early Years
#
#                                                 review  raiting  quality
# 0    I have enjoyed most of the computeranimated fi...      8.1        1
# 1    Shortly after Dreamworks screwed up with the u...      8.0        1
# 2    Yes you heard me Iron Man 3 is an improvement ...      7.2        0
# 3    This movie ha everything a good blockbuster sh...      7.3        0
# 4    Personally Ive never seen anything a original ...      8.6        1
# 5    Having seen the previous four Mission Impossib...      7.4        0
# 6    Eve Morgan is a school superintendent whose ne...      6.2        0
# 7    Let me start off by saying that I am a big Har...      7.0        0
# 8    Like everybody else back in 1987 I wa really i...      5.7        0
# 9                                                  NaN      7.5        0
# 10   Rambo First Blood Part II 1985 is my personal ...      6.4        0
# 11   This is one of those action movie that it only...      7.1        0
# 12   When I heard that there wa to be a film versio...      7.9        0
# 13   Here is one film that lived up to it hype and ...      8.8        1
# 14   Yes youll undoubtedly spot some of Keanus more...      6.1        0
# 15   There is no way so many people would be AMAZED...      6.3        0
# 16   I loved it I am a big fan of standup comedy an...      7.9        0
# 17   Quentin Tarantino one of the most iconic direc...      8.4        1
# 18   Up until now I wa convinced that from the 4th ...      7.7        0
# 19   After not really caring for the last pirate of...      6.6        0
# 20   I loved this film Its funny and creative Kept ...      6.3        0
# 21   A must watch movie forNew kinda film for tamil...      9.2        1
# 22   Dumb Brutal and a Lot of Boobs Absolutely enjo...      5.3        0
# 23   I have not seen a single ad for this movie The...      7.0        0
# 24   To preface I rarely trust review that have 101...      7.4        0
# 25   The Hunger Games story continues with the thir...      6.7        0
# 26   The movie is good Im a Denzel fan and a Fuqua ...      6.8        0
# 27   Every single cliche of an actionhorroradventur...      6.2        0
# 28   Not being a huge fan of superhero movie I didn...      8.4        1
# 29   Very investing movie with someI wa lucky enoug...      7.6        0
# ..                                                 ...      ...      ...
# 171  What in Gods name wa this Everything reek of c...      6.0        0
# 172  Everyone seems to complain that the plot in th...      7.1        0
# 173  First Blood 1982 is the best in the Rambo seri...      7.7        0
# 174                                                NaN      6.1        0
# 175  It sickened me in the past to see the Batman m...      8.3        1
# 176  Truly excellent film and definitely Ocsar wort...      8.0        1
# 177  There is much to like here and not much that i...      7.9        0
# 178  AntMan is badass spectacular heist adventure m...      7.3        0
# 179  Ive noticed quite a few review here from book ...      7.6        0
# 180  The breeze stirred the neatly cut bush of Tiso...      7.6        0
# 181  Why do I want to write the 234th comment on Th...      9.3        1
# 182  I almost didnt bother with this sequel The fir...      6.5        0
# 183  Wow there are a lot of people who dont like th...      7.0        0
# 184  AWE wa a decent close to the trilogy although ...      7.1        0
# 185  What happens when you take a classic beloved c...      5.9        0
# 186  Sometimes when I read review about movie on IM...      7.5        0
# 187  Star Wars Episode IV A New Hope 1977 is a clas...      8.6        1
# 188  Dark and twisted David Finchers stylish new my...      8.1        1
# 189  They are making too many movie I think The sto...      7.2        0
# 190  From the beginning to end the directing wa so ...      8.1        1
# 191  I dont understand the hate for this film or wh...      7.1        0
# 192  This isnt just a beautifully crafted gangster ...      9.2        1
# 193  Trailer looked great but the actual movie is j...      6.1        0
# 194  The script and acting are good enough so far t...      6.2        0
# 195  This wa a fun movie to watch much better than ...      7.4        0
# 196  Wow color me impressed I went in with low expe...      7.1        0
# 197  Might a well watch the cut scene from a video ...      6.5        0
# 198  A feast for the eye Dark and uncompromising Wi...      8.2        1
# 199  Truly a bad cover version that includes the st...      8.0        1
# 200  There is a certain grace and tranquility to th...      6.8        0
#
# [201 rows x 4 columns]

# %%
lemmatizer = WordNetLemmatizer()

# %%
import string
exclude = set(string.punctuation)

# %%
data['review'] = data['review'].apply(lambda x: "".join(i for i in x if i not in exclude))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-b71b99673024> in <module>()
# ----> 1 data['review'] = data['review'].apply(lambda x: "".join(i for i in x if i not in exclude))
#
# C:\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3192             else:
#    3193                 values = self.astype(object).values
# -> 3194                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3195
#    3196         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src\inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-17-b71b99673024> in <lambda>(x)
# ----> 1 data['review'] = data['review'].apply(lambda x: "".join(i for i in x if i not in exclude))
#
# TypeError: 'float' object is not iterable

# %%
data['review'] = data['review'].apply(lambda x: "".join(i for i in x if i not in exclude))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-b71b99673024> in <module>()
# ----> 1 data['review'] = data['review'].apply(lambda x: "".join(i for i in x if i not in exclude))
#
# C:\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3192             else:
#    3193                 values = self.astype(object).values
# -> 3194                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3195
#    3196         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src\inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-11-b71b99673024> in <lambda>(x)
# ----> 1 data['review'] = data['review'].apply(lambda x: "".join(i for i in x if i not in exclude))
#
# TypeError: 'float' object is not iterable

# %%
data['review'] = data['review'].apply(lambda x:
                                      " ".join(lemmatizer.lemmatize(i) for i in x.split()))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-0c0c659f053d> in <module>()
# ----> 1 data['review'] = data['review'].apply(lambda x:
#       2                                       " ".join(lemmatizer.lemmatize(i) for i in x.split()))
#
# C:\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3192             else:
#    3193                 values = self.astype(object).values
# -> 3194                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3195
#    3196         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src\inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-13-0c0c659f053d> in <lambda>(x)
#       1 data['review'] = data['review'].apply(lambda x:
# ----> 2                                       " ".join(lemmatizer.lemmatize(i) for i in x.split()))
#
# AttributeError: 'float' object has no attribute 'split'

# %%
vectorizer = CountVectorizer().fit(data['review'])
x = v.fit_transform(df['Review'].values.astype('U'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-a0efd7d36f92> in <module>()
# ----> 1 vectorizer = CountVectorizer().fit(data['review'])
#
# C:\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py in fit(self, raw_documents, y)
#     834         self
#     835         """
# --> 836         self.fit_transform(raw_documents)
#     837         return self
#     838
#
# C:\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py in fit_transform(self, raw_documents, y)
#     867
#     868         vocabulary, X = self._count_vocab(raw_documents,
# --> 869                                           self.fixed_vocabulary_)
#     870
#     871         if self.binary:
#
# C:\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py in _count_vocab(self, raw_documents, fixed_vocab)
#     790         for doc in raw_documents:
#     791             feature_counter = {}
# --> 792             for feature in analyze(doc):
#     793                 try:
#     794                     feature_idx = vocabulary[feature]
#
# C:\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py in <lambda>(doc)
#     264
#     265             return lambda doc: self._word_ngrams(
# --> 266                 tokenize(preprocess(self.decode(doc))), stop_words)
#     267
#     268         else:
#
# C:\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py in decode(self, doc)
#     117
#     118         if doc is np.nan:
# --> 119             raise ValueError("np.nan is an invalid document, expected byte or "
#     120                              "unicode string.")
#     121
#
# ValueError: np.nan is an invalid document, expected byte or unicode string.
